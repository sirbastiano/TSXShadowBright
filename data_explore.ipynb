# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plotty import plot_csv

# %%
df = plot_csv("/Data_large/marine/PythonProjects/OtherProjects/Sciarra/logs/segmentation_model_e20/version_0/metrics.csv")
